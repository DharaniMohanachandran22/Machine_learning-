# %% [markdown]
# <a href="https://colab.research.google.com/github/DharaniMohanachandran22/Machine_learning-/blob/main/Pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
a=np.array([10,20,30,40,50])
a
# Out:
# array([10, 20, 30, 40, 50])

# %%
s=pd.Series([10,20,12,40,30])
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0    10
# 1    20
# 2    12
# 3    40
# 4    30
# dtype: int64

# %%
s[3]
# Out:
# 40

# %%
s.drop(3)
# Out:
# 0    10
# 1    20
# 2    12
# 4    30
# dtype: int64

# %%
s[3]
# Out:
# 40

# %%
s.drop(3,inplace=True)

# %%
#s[3]#we remove 3rd index

# %%
s
# Out:
# 0    10
# 1    20
# 2    12
# 4    30
# dtype: int64

# %%
s.iloc[3] #iloc acces only with inddex
# Out:
# 30

# %%
s
# Out:
# 0    10
# 1    20
# 2    12
# 4    30
# dtype: int64

# %%
s.loc[4] # loc acces with value
# Out:
# 30

# %%
s.index
# Out:
# Int64Index([0, 1, 2, 4], dtype='int64')

# %%
ss= pd.Series([10,12,13,44,56],index=['dhara','b','c','d','dhara'])#index=['a','b','c']
ss
# Out:
# dhara    10
# b        12
# c        13
# d        44
# dhara    56
# dtype: int64

# %%
ss.loc['dhara']
# Out:
# dhara    10
# dhara    56
# dtype: int64

# %%
ss.iloc[1] #iloc[dhara] -->error
# Out:
# 12

# %%
data=[['dhara',12,'22-11-2003'],['mukil',13,'21-12-2000'],['aruna',44,'13-8-2002'],['mohan',45,'15-2-2004']]
data #output -->list
# Out:
# [['dhara', 12, '22-11-2003'],
#  ['mukil', 13, '21-12-2000'],
#  ['aruna', 44, '13-8-2002'],
#  ['mohan', 45, '15-2-2004']]

# %%
df=pd.DataFrame(data)
df
# Out:
#        0   1           2
# 0  dhara  12  22-11-2003
# 1  mukil  13  21-12-2000
# 2  aruna  44   13-8-2002
# 3  mohan  45   15-2-2004

# %%
df[0:3]
# Out:
#        0   1           2
# 0  dhara  12  22-11-2003
# 1  mukil  13  21-12-2000
# 2  aruna  44   13-8-2002

# %%
print(df[0][0])
print(df[0][1])
print(df[1][1])
# Out:
# dhara
# mukil
# 13

# %%
df[1:2] #2--> act as explicite
# Out:
#        0   1           2
# 1  mukil  13  21-12-2000

# %%
df=pd.DataFrame(data,columns=['First Name','Age','DOB'])
df
# Out:
#   First Name  Age         DOB
# 0      dhara   12  22-11-2003
# 1      mukil   13  21-12-2000
# 2      aruna   44   13-8-2002
# 3      mohan   45   15-2-2004

# %%
df['First Name']
# Out:
# 0    dhara
# 1    mukil
# 2    aruna
# 3    mohan
# Name: First Name, dtype: object

# %%
df['Age']
# Out:
# 0    12
# 1    13
# 2    44
# 3    45
# Name: Age, dtype: int64

# %%
df['First Name'][0]
# Out:
# 'dhara'

# %%
df.loc[0,'First Name']
# Out:
# 'dhara'

# %%
#df[0][0] --> error
df[0:1]
# Out:
#   First Name  Age         DOB
# 0      dhara   12  22-11-2003

# %%
data=[['dhara',12,'22-11-2003'],['mukil',13,'21-12-2000'],['aruna',44,'13-8-2002'],['mohan',45,'15-2-2004']]
df=pd.DataFrame(data)
df=pd.DataFrame(data,columns=['First Name','Age','DOB'])
df
df=pd.DataFrame(data,index=['DATA1','DATA2','DATA3','DATA4'])
df
# Out:
#            0   1           2
# DATA1  dhara  12  22-11-2003
# DATA2  mukil  13  21-12-2000
# DATA3  aruna  44   13-8-2002
# DATA4  mohan  45   15-2-2004

# %%
a=pd.Series([5,10,15,20,35])
a
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    35
# dtype: int64

# %%
a.hist(bins=2)
a.hist(bins=3)
# Out:
# <Axes: >

# %%
a.plot()
# Out:
# <Axes: >

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a=pd.Series([5,10,15,20,25])
a=a.to_numpy()
type(a)
# Out:
# numpy.ndarray

# %%
df.head()
# Out:
#            0   1           2
# DATA1  dhara  12  22-11-2003
# DATA2  mukil  13  21-12-2000
# DATA3  aruna  44   13-8-2002
# DATA4  mohan  45   15-2-2004

# %%
df.head(1)
# Out:
#            0   1           2
# DATA1  dhara  12  22-11-2003

# %%
df.tail(2)
# Out:
#            0   1          2
# DATA3  aruna  44  13-8-2002
# DATA4  mohan  45  15-2-2004

# %%
#None,'',' ','-' '?',' nil',np.nan(not a number)

# %%
data=[['dhara',12,'22-11-2003'],['mukil',None,None],['aruna',44,'13-8-2002'],['mohan',45,'15-2-2004']]
d=pd.DataFrame(data)
d=pd.DataFrame(data,columns=['First Name','Age','DOB'])
d #None --> age -->Nan --> not a number
# Out:
#   First Name   Age         DOB
# 0      dhara  12.0  22-11-2003
# 1      mukil   NaN        None
# 2      aruna  44.0   13-8-2002
# 3      mohan  45.0   15-2-2004

# %%
d.isnull().sum() #count
# Out:
# First Name    0
# Age           1
# DOB           1
# dtype: int64

# %%
d.isnull()
# Out:
#    First Name    Age    DOB
# 0       False  False  False
# 1       False   True   True
# 2       False  False  False
# 3       False  False  False

# %%
d.dropna()
# Out:
#   First Name   Age         DOB
# 0      dhara  12.0  22-11-2003
# 2      aruna  44.0   13-8-2002
# 3      mohan  45.0   15-2-2004

# %%
d
# Out:
#   First Name   Age         DOB
# 0      dhara  12.0  22-11-2003
# 1      mukil   NaN        None
# 2      aruna  44.0   13-8-2002
# 3      mohan  45.0   15-2-2004

# %%
#d.dropna(inplace=True)
#d ==> #run all

# %%
d.drop(['Age'],axis=1,inplace=True)
d
# Out:
#   First Name         DOB
# 0      dhara  22-11-2003
# 1      mukil        None
# 2      aruna   13-8-2002
# 3      mohan   15-2-2004

# %%
d.drop([0,2])
# Out:
#   First Name        DOB
# 1      mukil       None
# 3      mohan  15-2-2004

# %%
d
# Out:
#   First Name         DOB
# 0      dhara  22-11-2003
# 1      mukil        None
# 2      aruna   13-8-2002
# 3      mohan   15-2-2004

# %%
#d.drop([0,2],inplace=True)

# %%
a
# Out:
# array([ 5, 10, 15, 20, 25])

# %%
a>10
# Out:
# array([False, False,  True,  True,  True])

# %%
a[a>10]
# Out:
# array([15, 20, 25])

# %%
a[a%2!=0]
# Out:
# array([ 5, 15, 25])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
d
# Out:
#   First Name         DOB
# 0      dhara  22-11-2003
# 1      mukil        None
# 2      aruna   13-8-2002
# 3      mohan   15-2-2004

# %%
df.info
# Out:
# <bound method DataFrame.info of            0   1           2
# DATA1  dhara  12  22-11-2003
# DATA2  mukil  13  21-12-2000
# DATA3  aruna  44   13-8-2002
# DATA4  mohan  45   15-2-2004>

# %%
d.info() #all columns in objec type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  4 non-null      object
#  1   DOB         3 non-null      object
# dtypes: object(2)
# memory usage: 192.0+ bytes

# %%
d['First Name'].str.contains('a') #d['first Name'.contains]==>above data is string we can't acess directly // 'a' is a string so==>str.contains
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# Name: First Name, dtype: bool

# %%
# attributes of panda
print(d.shape)
print(d.size)
print(d.axes)
print(d.ndim)
print(d.dtypes)
print(d.index)
print(d.columns)
print(d.values)
# Out:
# (4, 2)
# 8
# [RangeIndex(start=0, stop=4, step=1), Index(['First Name', 'DOB'], dtype='object')]
# 2
# First Name    object
# DOB           object
# dtype: object
# RangeIndex(start=0, stop=4, step=1)
# Index(['First Name', 'DOB'], dtype='object')
# [['dhara' '22-11-2003']
#  ['mukil' None]
#  ['aruna' '13-8-2002']
#  ['mohan' '15-2-2004']]

# %%
d.tail()
# Out:
#   First Name         DOB
# 0      dhara  22-11-2003
# 1      mukil        None
# 2      aruna   13-8-2002
# 3      mohan   15-2-2004

# %%
d2=pd.concat([d,d])
d2
# Out:
#   First Name         DOB
# 0      dhara  22-11-2003
# 1      mukil        None
# 2      aruna   13-8-2002
# 3      mohan   15-2-2004
# 0      dhara  22-11-2003
# 1      mukil        None
# 2      aruna   13-8-2002
# 3      mohan   15-2-2004

# %%
d.describe(include='all')
d
# Out:
#   First Name         DOB
# 0      dhara  22-11-2003
# 1      mukil        None
# 2      aruna   13-8-2002
# 3      mohan   15-2-2004

# %%
d['First Name']
# Out:
# 0    dhara
# 1    mukil
# 2    aruna
# 3    mohan
# Name: First Name, dtype: object

# %%
d[['First Name','DOB']]
# Out:
#   First Name         DOB
# 0      dhara  22-11-2003
# 1      mukil        None
# 2      aruna   13-8-2002
# 3      mohan   15-2-2004

# %%
d.loc[0][0]# we can acces iloc in locfunction
# Out:
# 'dhara'

# %%
d.loc[0,'First Name']
# Out:
# 'dhara'

# %%
print(d.iloc[0][0])
print(d.iloc[0,1])
print(d.iloc[0,0])
# Out:
# dhara
# 22-11-2003
# dhara

# %%
d['DOB'][1]='13.4.2000'
d.head(2)
# Out:
#   First Name         DOB
# 0      dhara  22-11-2003
# 1      mukil   13.4.2000

# %%
import pandas as pd
d=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
print(d)
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#type(d.item_price[[0]])

# %%
d.item_price =d.item_price.str.replace('$','')
d.head(10)
# Out:
# <ipython-input-173-2ee5d3bf66db>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   d.item_price =d.item_price.str.replace('$','')
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
# ...

# %%
d.item_price=d.item_price.astype(float)
print(d)
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
type(d.item_price[0])
# Out:
# numpy.float64

# %%
print(d.item_price*100)
# Out:
# 0        239.0
# 1        339.0
# 2        339.0
# 3        239.0
# 4       1698.0
#          ...
# 4617    1175.0
# 4618    1175.0
# 4619    1125.0
# 4620     875.0
# 4621     875.0
# Name: item_price, Length: 4622, dtype: float64

# %%
d.item_name.unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
df_drink= d[d.item_price <1.1]
print(df_drink)
# Out:
#       order_id  quantity      item_name choice_description  item_price
# 28          14         1    Canned Soda       [Dr. Pepper]        1.09
# 34          17         1  Bottled Water                NaN        1.09
# 53          24         1    Canned Soda           [Sprite]        1.09
# 87          38         1  Bottled Water                NaN        1.09
# 107         47         1    Canned Soda       [Dr. Pepper]        1.09
# ...        ...       ...            ...                ...         ...
# 3936      1578         1    Canned Soda  [Diet Dr. Pepper]        1.09
# 4001      1602         1  Bottled Water                NaN        1.09
# 4008      1604         1    Canned Soda        [Diet Coke]        1.09
# 4051      1621         1    Canned Soda           [Sprite]        1.09
# 4069      1629         1  Bottled Water                NaN        1.09
#
# [106 rows x 5 columns]

# %%
print(df_drink.item_name.unique())
print(df_drink.item_name.nunique())
# Out:
# ['Canned Soda' 'Bottled Water']
# 2

# %%
df_drink.item_name.value_counts()
# Out:
# Canned Soda      84
# Bottled Water    22
# Name: item_name, dtype: int64

# %%
d
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
d[d.item_name=='Chicken Salad Bowl']
# Out:
#       order_id  quantity           item_name  \
# 44          20         1  Chicken Salad Bowl
# 135         60         2  Chicken Salad Bowl
# 213         94         2  Chicken Salad Bowl
# 256        111         1  Chicken Salad Bowl
# 315        137         2  Chicken Salad Bowl
# ...        ...       ...                 ...
# 4561      1813         2  Chicken Salad Bowl
# 4580      1822         1  Chicken Salad Bowl
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 44    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        8.75
# 135   [Tomatillo Green Chili Salsa, [Sour Cream, Che...       22.50
# 213   [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       22.50
# 256   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...        8.75
# 315             [Fresh Tomato Salsa, Fajita Vegetables]       17.50
# ...

# %%
d[d.item_name=='Steak Burrito'].choice_description.value_counts()
# Out:
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream]]                                                        12
# [Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]                                     6
# [Tomatillo Green Chili Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]                                        6
# [[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]     5
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                            5
#                                                                                                                             ..
# [Fresh Tomato Salsa, [Rice, Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]                                    1
# ...

# %%
d[d.item_name=='Steak Burrito'].choice_description.nunique()
# Out:
# 251

# %%
d.dropna(inplace=True)

# %%
d[d.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
d[(d.item_price<10) &(d.item_name =='Chicken Bowl')]
# Out:
#       order_id  quantity     item_name  \
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 76          34         1  Chicken Bowl
# 78          34         1  Chicken Bowl
# 99          44         1  Chicken Bowl
# ...        ...       ...           ...
# 4583      1823         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# 76    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        8.75
# 78    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
# 99    [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...        8.75
# ...                                                 ...         ...
# ...

# %%
d[(d.item_price<10) &(d.item_name =='Chicken Bowl')].sort_values(['item_price'])
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3396      1362         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# ...        ...       ...           ...
# 1876       759         1  Chicken Bowl
# 1852       751         1  Chicken Bowl
# 1851       750         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3396  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...        8.49
# ...                                                 ...         ...
# ...

# %%
q=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
q
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
q[(q.star_rating>8)&(q.genre=='Crime')].sort_values(['duration'])
# Out:
#      star_rating                        title content_rating  genre  duration  \
# 258          8.1  The Cabinet of Dr. Caligari        UNRATED  Crime        67
# 272          8.1                  The Killing       APPROVED  Crime        85
# 225          8.1                       3-Iron              R  Crime        88
# 98           8.4                     Rashomon        UNRATED  Crime        88
# 233          8.1      The Night of the Hunter       APPROVED  Crime        92
# 175          8.2                Touch of Evil          PG-13  Crime        95
# 234          8.1                     La Haine      NOT RATED  Crime        98
# 176          8.2                        Fargo              R  Crime        98
# 63           8.4                            M      NOT RATED  Crime        99
# 178          8.2                The 400 Blows      NOT RATED  Crime        99
# 90           8.4               Reservoir Dogs              R  Crime        99
# ...

# %%
q[(q.actors_list.str.contains("Leonardo DiCaprio"))]
# Out:
#      star_rating                        title content_rating      genre  \
# 11           8.8                    Inception          PG-13     Action
# 49           8.5                 The Departed              R      Crime
# 59           8.5             Django Unchained              R    Western
# 143          8.2      The Wolf of Wall Street              R  Biography
# 244          8.1               Shutter Island              R    Mystery
# 309          8.0                Blood Diamond              R  Adventure
# 340          8.0          Catch Me If You Can          PG-13  Biography
# 562          7.8  What's Eating Gilbert Grape          PG-13      Drama
# 620          7.7                      Titanic          PG-13      Drama
# 828          7.5            Gangs of New York              R      Crime
# 888          7.5                  The Aviator          PG-13  Biography
#
#      duration                                        actors_list
# ...

# %%
ufo=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
ufo.dropna(subset=['City','Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
ufo['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
ufo['Shape Reported'].isnull().sum()
# Out:
# 2644

# %%
ufo['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
r=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
r.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
r.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
r[r.continent == 'Asia'].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
r[r.continent == 'Asia'].beer_servings.agg(['mean','min','max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
r.groupby('continent').beer_servings.agg(['mean','min','max'])
# Out:
#                      mean  min  max
# continent
# Africa          61.471698    0  376
# Asia            37.045455    0  247
# Europe         193.777778    0  361
# North America  145.434783    1  285
# Oceania         89.687500    0  306
# South America  175.083333   93  333
